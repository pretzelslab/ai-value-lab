# %% [markdown]
# # 01 Baseline Economics
#
# This notebook validates the current state cost before introducing AI.

# %%
from ai_value_lab import BaselineInputs, calculate_baseline

inputs = BaselineInputs()
result = calculate_baseline(inputs)
result

# %% [markdown]
# ## Questions to investigate
#
# 1. Which assumptions are measured versus estimated?
# 2. Does loaded hourly cost include benefits and overhead?
# 3. Is rework already included in average handling time?
# 4. Which costs are material enough to include in the baseline?
